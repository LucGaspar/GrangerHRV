# %%
import pandas as pd
import datetime as datetime
import numpy as np

# %%
hrv = pd.read_csv(r'C:\Users\LucasMarquesGasparin\Desktop\Learning\TCC\ParticipanteA x ParticipanteB\Multi\ParticipanteA_RR.csv', parse_dates = ['Time'])

# %%
hrvOutlier = hrv[hrv.index.isin([643, 644, 645, 646, 647, 648, 863, 864, 865])]

# %%
from random import randrange

while True:
    lis = []
    for i in range(11):
        q = randrange(610, 700)
        lis.append(q)
    su = sum(lis)
    print(lis, su)
    if (su == 7041):
        break
# Out:
# [654, 613, 653, 672, 681, 638, 667, 629, 673, 630, 685] 7195
# [647, 679, 681, 612, 623, 660, 645, 684, 616, 679, 648] 7174
# [652, 615, 644, 670, 685, 672, 659, 696, 628, 641, 612] 7174
# [673, 650, 639, 664, 611, 615, 646, 651, 640, 680, 691] 7160
# [654, 643, 688, 615, 667, 681, 624, 631, 699, 689, 684] 7275
# [680, 669, 699, 685, 610, 645, 619, 698, 617, 618, 623] 7163
# [643, 616, 679, 625, 624, 613, 671, 669, 641, 634, 622] 7037
# [615, 663, 620, 668, 630, 659, 675, 652, 695, 620, 618] 7115
# [638, 634, 677, 688, 661, 647, 689, 633, 657, 651, 651] 7226
# [661, 690, 699, 646, 686, 610, 618, 622, 628, 656, 636] 7152
# [650, 644, 657, 686, 670, 681, 689, 667, 637, 665, 675] 7321
# [622, 685, 626, 673, 659, 689, 618, 687, 669, 619, 673] 7220
# [686, 646, 640, 656, 693, 687, 625, 694, 699, 613, 624] 7263
# [628, 633, 657, 652, 630, 614, 659, 677, 611, 651, 663] 7075
# [667, 691, 619, 620, 671, 610, 623, 652, 673, 686, 610] 7122
# ...

# %%
# Tipo 1: Missing
# R2 = 2RR1

# Tipo 2: Wrong detection
# RR1 = RR2 + RR3 (os dois seguintes são a soma do anterior correto)

# Tipo 3: Ectopic Beat
# 2RR1 = RR2 + RR3

hrvOutlier['RR Interval [ms]'][644] = hrvOutlier['RR Interval [ms]'][644] + hrvOutlier['RR Interval [ms]'][645]
hrvOutlier.drop([645], inplace = True)
# Out:
# C:\Users\LucasMarquesGasparin\AppData\Local\Continuum\anaconda3\envs\TCC\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
hrvHalf = hrvOutlier['RR Interval [ms]'][864] / 2
hrvOutlier = hrvOutlier.append({'RR Interval [ms]' : hrvHalf, 'Time' : hrvOutlier.Time[863] + datetime.timedelta(milliseconds = hrvHalf)}, ignore_index = True)
hrvOutlier = hrvOutlier.append({'RR Interval [ms]' : hrvHalf, 'Time' : hrvOutlier.Time[6]}, ignore_index = True).drop([6])

# %%
TimeG = hrvOutlier['Time'][1] 
TimeI = hrvOutlier['Time'][3]
h = hrvOutlier[hrvOutlier.index == 2]

q = pd.DataFrame()
lis = [665, 611, 622, 636, 619, 637, 681, 675, 627, 654]
for i in range(10):
    q = q.append({'RR Interval [ms]' : lis[i], 'Time' : TimeG + datetime.timedelta(milliseconds = lis[i])}, ignore_index = True)
    TimeG = TimeG + datetime.timedelta(milliseconds = lis[i])

q = q.append({'RR Interval [ms]' : 614.993, 'Time' : hrvOutlier['Time'][3] - datetime.timedelta(milliseconds = hrvOutlier['RR Interval [ms]'][3])}, ignore_index = True)

hrvOutlier = hrvOutlier.drop([2]).append(q, ignore_index = True).sort_values(by = ['Time'])

hrvOutlier
# Out:
#     RR Interval [ms]                       Time
# 0         623.046875 2019-11-06 11:12:51.593488
# 1         695.312500 2019-11-06 11:12:52.006574
# 8         665.000000 2019-11-06 11:12:52.671574
# 9         611.000000 2019-11-06 11:12:53.282574
# 10        622.000000 2019-11-06 11:12:53.904574
# 11        636.000000 2019-11-06 11:12:54.540574
# 12        619.000000 2019-11-06 11:12:55.159574
# 13        637.000000 2019-11-06 11:12:55.796574
# 14        681.000000 2019-11-06 11:12:56.477574
# 15        675.000000 2019-11-06 11:12:57.152574
# 16        627.000000 2019-11-06 11:12:57.779574
# 17        654.000000 2019-11-06 11:12:58.433574
# 18        614.993000 2019-11-06 11:12:59.048567
# 2         623.046875 2019-11-06 11:12:59.671614
# 3         634.765625 2019-11-06 11:13:00.306380
# 4         647.460938 2019-11-06 11:15:12.980207
# 6         643.554688 2019-11-06 11:15:13.623762
# 7         643.554688 2019-11-06 11:15:14.267316
# 5         643.554688 2019-11-06 11:15:14.910871

# %%
hrv.drop([643, 644, 645, 646, 647, 648, 863, 864, 865]).append(hrvOutlier, ignore_index = True).sort_values(by = ['Time']).to_csv(r'C:\Users\LucasMarquesGasparin\Desktop\Learning\TCC\ParticipanteA x ParticipanteB\Multi\ParticipanteA_RR.csv', index = None)

# %%
hrv = pd.read_csv(r'C:\Users\LucasMarquesGasparin\Desktop\Learning\TCC\ParticipanteA x ParticipanteB\Multi\ParticipanteA_RR.csv', parse_dates = ['Time'])

# %%
hrvOutlier = hrv[hrv.index.isin([868, 869, 870, 871])]

# %%
hrvOutlier['RR Interval [ms]'][870] = hrvOutlier['RR Interval [ms]'][869] + hrvOutlier['RR Interval [ms]'][870]
# Out:
# C:\Users\LucasMarquesGasparin\AppData\Local\Continuum\anaconda3\envs\TCC\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hrvOutlier = hrvOutlier.drop([869])

# %%
hrvOutlier
# Out:
#      RR Interval [ms]                       Time
# 868        667.968750 2019-11-06 11:15:11.048566
# 870        658.203125 2019-11-06 11:15:11.706769
# 871        625.976562 2019-11-06 11:15:12.332746

# %%
hrv.drop([868, 869, 870, 871]).append(hrvOutlier, ignore_index = True).sort_values(by = ['Time']).to_csv(r'C:\Users\LucasMarquesGasparin\Desktop\Learning\TCC\ParticipanteA x ParticipanteB\Multi\ParticipanteA_RR.csv', index = None)

# %%
hrv = pd.read_csv(r'C:\Users\LucasMarquesGasparin\Desktop\Learning\TCC\ParticipanteA x ParticipanteB\Multi\sound\ParticipanteA_RR.csv', parse_dates = ['Time'])

# %%
hrvOutlier = hrv[hrv.index == 98]

# %%
q = (hrvOutlier['RR Interval [ms]'] / 3).values[0]

# %%
for i in range(3):
    hrv = hrv.append({'RR Interval [ms]' : q, 'Time' : hrv['Time'][97] + datetime.timedelta(milliseconds = q * (i + 1))}, ignore_index = True)

# %%
hrv = hrv.sort_values(by = ['Time'])

# %%
hrv = hrv.drop([98])

# %%
hrv = hrv.reset_index(drop = True)

# %%
hrv[hrv.index.isin([97, 98, 99, 100, 101, 102])]
# Out:
#      RR Interval [ms]                       Time
# 97         713.867188 2019-11-06 10:28:30.037000
# 98         734.700521 2019-11-06 10:28:30.771701
# 99         734.700521 2019-11-06 10:28:31.506401
# 100        734.700521 2019-11-06 10:28:32.241102
# 101        727.539062 2019-11-06 10:28:32.968000
# 102        702.148438 2019-11-06 10:28:33.670000

# %%
hrv.to_csv(r'C:\Users\LucasMarquesGasparin\Desktop\Learning\TCC\ParticipanteA x ParticipanteB\Multi\sound\ParticipanteA_RR.csv', index = None)
