# %%
import glob

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../Data/Processed/2.csv')

# %%
# SDNN
plt.figure(figsize=(10,5))
plt.plot('Instante', f'RR_A',  data=df, marker='', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'Instante', f'RR_B',  data=df, marker='', markerfacecolor='olive', markersize=12, color='palegoldenrod', linewidth=4)
plt.legend()
plt.xlabel('Tempo (ms)')
plt.ylabel('milisegundos')
title = f'RR_A x RR_B'
plt.title(title)
# Out:
# Text(0.5, 1.0, 'RR_A x RR_B')
