# %%
import pandas as pd
import glob

# %%
x = glob.glob(r'C:\Users\LucasMarquesGasparin\Desktop\Learning\TCC\Time Series\Data\*.csv')

# %%
x
# Out:
# ['C:\\Users\\LucasMarquesGasparin\\Desktop\\Learning\\TCC\\Time Series\\Data\\1.csv',
#  'C:\\Users\\LucasMarquesGasparin\\Desktop\\Learning\\TCC\\Time Series\\Data\\2.csv',
#  'C:\\Users\\LucasMarquesGasparin\\Desktop\\Learning\\TCC\\Time Series\\Data\\3.csv',
#  'C:\\Users\\LucasMarquesGasparin\\Desktop\\Learning\\TCC\\Time Series\\Data\\4.csv',
#  'C:\\Users\\LucasMarquesGasparin\\Desktop\\Learning\\TCC\\Time Series\\Data\\5.csv',
#  'C:\\Users\\LucasMarquesGasparin\\Desktop\\Learning\\TCC\\Time Series\\Data\\6.csv']

# %%
q = pd.read_csv(x[0], parse_dates = ['Time'])

# %%
q
# Out:
#                           Time  Pulse_x  Pulse_y  BallPosX  BallPosY  \
# 0      2019-11-06 10:27:23.153        0        0      72.0      99.0
# 1      2019-11-06 10:27:23.154        0        0      72.0      99.0
# 2      2019-11-06 10:27:23.155        0        0      73.0      98.0
# 3      2019-11-06 10:27:23.156        0        0      73.0      98.0
# 4      2019-11-06 10:27:23.157        0        0      73.0      98.0
# ...                        ...      ...      ...       ...       ...
# 855125 2019-11-06 10:41:38.278        0        0     735.0     130.0
# 855126 2019-11-06 10:41:38.279        0        0     736.0     129.0
# 855127 2019-11-06 10:41:38.280        0        0     736.0     129.0
# 855128 2019-11-06 10:41:38.281        0        0     737.0     128.0
# 855129 2019-11-06 10:41:38.282        0        0     737.0     128.0
#
#         BallSpeed   PosB   PosA  ScoreB  ScoreA Resultado Attacking  \
# 0             5.0   69.0   22.0     0.0     0.0    Empate         A
# ...
