# %%
import pandas as pd
import statsmodels.tsa.stattools as stats
import numpy as np
import glob

# %%
filesPath = glob.glob('../Time Series/Testes em 100/*.csv')

# %%
Granger = pd.DataFrame(columns = ['windowSize (ms)', 'Modo', 'Direction', 'Lag', 'Chi2', 'p'])
timeSeriesM = pd.read_csv(filesPath[0])
timeSeriesS = pd.read_csv(filesPath[1])
Z1 = timeSeriesM[['Pulse X', 'Pulse Y']].to_numpy(dtype = bool)
Z2 = timeSeriesM[['Pulse Y', 'Pulse X']].to_numpy(dtype = bool)
Z3 = timeSeriesS[['Pulse X', 'Pulse Y']].to_numpy(dtype = bool)
Z4 = timeSeriesS[['Pulse Y', 'Pulse X']].to_numpy(dtype = bool)
result1 = stats.grangercausalitytests(Z1, 15, addconst=True, verbose=True)
result2 = stats.grangercausalitytests(Z2, 15, addconst=True, verbose=True)
result3 = stats.grangercausalitytests(Z3, 15, addconst=True, verbose=True)
result4 = stats.grangercausalitytests(Z4, 15, addconst=True, verbose=True)

for i in range(7, 15):
    delaySon = i + 1
    ssr_ftest = result1[delaySon][0]['ssr_ftest']
    ssr_qtest = result1[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'A->B', 'Modo': 'M', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    ssr_ftest = result3[delaySon][0]['ssr_ftest']
    ssr_qtest = result3[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'A->B', 'Modo': 'S', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    ssr_ftest = result2[delaySon][0]['ssr_ftest']
    ssr_qtest = result2[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'B->A', 'Modo': 'M', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])

    ssr_ftest = result4[delaySon][0]['ssr_ftest']
    ssr_qtest = result4[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'B->A', 'Modo': 'S', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    
Granger1 = Granger.copy()
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9644  , p=0.1611  , df_denom=8554, df_num=1
# ssr based chi2 test:   chi2=1.9650  , p=0.1610  , df=1
# likelihood ratio test: chi2=1.9648  , p=0.1610  , df=1
# parameter F test:         F=1.9644  , p=0.1611  , df_denom=8554, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9504  , p=0.3866  , df_denom=8551, df_num=2
# ssr based chi2 test:   chi2=1.9020  , p=0.3864  , df=2
# likelihood ratio test: chi2=1.9018  , p=0.3864  , df=2
# parameter F test:         F=0.9504  , p=0.3866  , df_denom=8551, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2495  , p=0.8617  , df_denom=8548, df_num=3
# ssr based chi2 test:   chi2=0.7491  , p=0.8616  , df=3
# likelihood ratio test: chi2=0.7491  , p=0.8616  , df=3
# parameter F test:         F=0.2495  , p=0.8617  , df_denom=8548, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8073  , p=0.1244  , df_denom=8545, df_num=4
# ssr based chi2 test:   chi2=7.2370  , p=0.1239  , df=4
# likelihood ratio test: chi2=7.2339  , p=0.1240  , df=4
# parameter F test:         F=1.8073  , p=0.1244  , df_denom=8545, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3241  , p=0.2506  , df_denom=8542, df_num=5
# ssr based chi2 test:   chi2=6.6289  , p=0.2497  , df=5
# likelihood ratio test: chi2=6.6263  , p=0.2499  , df=5
# parameter F test:         F=1.3241  , p=0.2506  , df_denom=8542, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2754  , p=0.9487  , df_denom=8539, df_num=6
# ssr based chi2 test:   chi2=1.6550  , p=0.9485  , df=6
# likelihood ratio test: chi2=1.6548  , p=0.9486  , df=6
# parameter F test:         F=0.2754  , p=0.9487  , df_denom=8539, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3336  , p=0.9389  , df_denom=8536, df_num=7
# ssr based chi2 test:   chi2=2.3396  , p=0.9387  , df=7
# likelihood ratio test: chi2=2.3393  , p=0.9387  , df=7
# parameter F test:         F=0.3336  , p=0.9389  , df_denom=8536, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.8086  , p=0.0042  , df_denom=8533, df_num=8
# ssr based chi2 test:   chi2=22.5134 , p=0.0040  , df=8
# likelihood ratio test: chi2=22.4838 , p=0.0041  , df=8
# parameter F test:         F=2.8086  , p=0.0042  , df_denom=8533, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.6921  , p=0.0040  , df_denom=8530, df_num=9
# ssr based chi2 test:   chi2=24.2829 , p=0.0039  , df=9
# likelihood ratio test: chi2=24.2485 , p=0.0039  , df=9
# parameter F test:         F=2.6921  , p=0.0040  , df_denom=8530, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.4710  , p=0.0060  , df_denom=8527, df_num=10
# ssr based chi2 test:   chi2=24.7707 , p=0.0058  , df=10
# likelihood ratio test: chi2=24.7348 , p=0.0059  , df=10
# parameter F test:         F=2.4710  , p=0.0060  , df_denom=8527, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.2748  , p=0.0091  , df_denom=8524, df_num=11
# ssr based chi2 test:   chi2=25.0899 , p=0.0088  , df=11
# likelihood ratio test: chi2=25.0531 , p=0.0090  , df=11
# parameter F test:         F=2.2748  , p=0.0091  , df_denom=8524, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.2573  , p=0.0076  , df_denom=8521, df_num=12
# ssr based chi2 test:   chi2=27.1675 , p=0.0073  , df=12
# likelihood ratio test: chi2=27.1245 , p=0.0074  , df=12
# parameter F test:         F=2.2573  , p=0.0076  , df_denom=8521, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.0642  , p=0.0132  , df_denom=8518, df_num=13
# ssr based chi2 test:   chi2=26.9202 , p=0.0128  , df=13
# likelihood ratio test: chi2=26.8779 , p=0.0129  , df=13
# parameter F test:         F=2.0642  , p=0.0132  , df_denom=8518, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.9691  , p=0.0164  , df_denom=8515, df_num=14
# ssr based chi2 test:   chi2=27.6617 , p=0.0158  , df=14
# likelihood ratio test: chi2=27.6171 , p=0.0160  , df=14
# parameter F test:         F=1.9691  , p=0.0164  , df_denom=8515, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.1359  , p=0.0064  , df_denom=8512, df_num=15
# ssr based chi2 test:   chi2=32.1546 , p=0.0061  , df=15
# likelihood ratio test: chi2=32.0943 , p=0.0063  , df=15
# parameter F test:         F=2.1359  , p=0.0064  , df_denom=8512, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6300  , p=0.2017  , df_denom=8554, df_num=1
# ssr based chi2 test:   chi2=1.6306  , p=0.2016  , df=1
# likelihood ratio test: chi2=1.6305  , p=0.2016  , df=1
# parameter F test:         F=1.6300  , p=0.2017  , df_denom=8554, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.1986  , p=0.0409  , df_denom=8551, df_num=2
# ssr based chi2 test:   chi2=6.4010  , p=0.0407  , df=2
# likelihood ratio test: chi2=6.3986  , p=0.0408  , df=2
# parameter F test:         F=3.1986  , p=0.0409  , df_denom=8551, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0539  , p=0.1041  , df_denom=8548, df_num=3
# ssr based chi2 test:   chi2=6.1667  , p=0.1038  , df=3
# likelihood ratio test: chi2=6.1645  , p=0.1039  , df=3
# parameter F test:         F=2.0539  , p=0.1041  , df_denom=8548, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3886  , p=0.0487  , df_denom=8545, df_num=4
# ssr based chi2 test:   chi2=9.5644  , p=0.0484  , df=4
# likelihood ratio test: chi2=9.5591  , p=0.0485  , df=4
# parameter F test:         F=2.3886  , p=0.0487  , df_denom=8545, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.1534  , p=0.0563  , df_denom=8542, df_num=5
# ssr based chi2 test:   chi2=10.7809 , p=0.0559  , df=5
# likelihood ratio test: chi2=10.7741 , p=0.0560  , df=5
# parameter F test:         F=2.1534  , p=0.0563  , df_denom=8542, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3139  , p=0.2469  , df_denom=8539, df_num=6
# ssr based chi2 test:   chi2=7.8956  , p=0.2458  , df=6
# likelihood ratio test: chi2=7.8920  , p=0.2461  , df=6
# parameter F test:         F=1.3139  , p=0.2469  , df_denom=8539, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1688  , p=0.3170  , df_denom=8536, df_num=7
# ssr based chi2 test:   chi2=8.1956  , p=0.3157  , df=7
# likelihood ratio test: chi2=8.1917  , p=0.3160  , df=7
# parameter F test:         F=1.1688  , p=0.3170  , df_denom=8536, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0516  , p=0.3943  , df_denom=8533, df_num=8
# ssr based chi2 test:   chi2=8.4294  , p=0.3927  , df=8
# likelihood ratio test: chi2=8.4252  , p=0.3931  , df=8
# parameter F test:         F=1.0516  , p=0.3943  , df_denom=8533, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9371  , p=0.4911  , df_denom=8530, df_num=9
# ssr based chi2 test:   chi2=8.4531  , p=0.4892  , df=9
# likelihood ratio test: chi2=8.4489  , p=0.4896  , df=9
# parameter F test:         F=0.9371  , p=0.4911  , df_denom=8530, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8438  , p=0.5862  , df_denom=8527, df_num=10
# ssr based chi2 test:   chi2=8.4586  , p=0.5841  , df=10
# likelihood ratio test: chi2=8.4544  , p=0.5845  , df=10
# parameter F test:         F=0.8438  , p=0.5862  , df_denom=8527, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.9712  , p=0.4703  , df_denom=8524, df_num=11
# ssr based chi2 test:   chi2=10.7117 , p=0.4677  , df=11
# likelihood ratio test: chi2=10.7050 , p=0.4683  , df=11
# parameter F test:         F=0.9712  , p=0.4703  , df_denom=8524, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.0662  , p=0.3843  , df_denom=8521, df_num=12
# ssr based chi2 test:   chi2=12.8323 , p=0.3813  , df=12
# likelihood ratio test: chi2=12.8227 , p=0.3821  , df=12
# parameter F test:         F=1.0662  , p=0.3843  , df_denom=8521, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.0300  , p=0.4183  , df_denom=8518, df_num=13
# ssr based chi2 test:   chi2=13.4323 , p=0.4150  , df=13
# likelihood ratio test: chi2=13.4217 , p=0.4158  , df=13
# parameter F test:         F=1.0300  , p=0.4183  , df_denom=8518, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.9940  , p=0.4561  , df_denom=8515, df_num=14
# ssr based chi2 test:   chi2=13.9631 , p=0.4525  , df=14
# likelihood ratio test: chi2=13.9517 , p=0.4533  , df=14
# parameter F test:         F=0.9940  , p=0.4561  , df_denom=8515, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.1477  , p=0.3064  , df_denom=8512, df_num=15
# ssr based chi2 test:   chi2=17.2786 , p=0.3025  , df=15
# likelihood ratio test: chi2=17.2611 , p=0.3035  , df=15
# parameter F test:         F=1.1477  , p=0.3064  , df_denom=8512, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0375  , p=0.8465  , df_denom=4936, df_num=1
# ssr based chi2 test:   chi2=0.0375  , p=0.8465  , df=1
# likelihood ratio test: chi2=0.0375  , p=0.8465  , df=1
# parameter F test:         F=0.0375  , p=0.8465  , df_denom=4936, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7293  , p=0.4823  , df_denom=4933, df_num=2
# ssr based chi2 test:   chi2=1.4601  , p=0.4819  , df=2
# likelihood ratio test: chi2=1.4599  , p=0.4819  , df=2
# parameter F test:         F=0.7293  , p=0.4823  , df_denom=4933, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.5181  , p=0.0145  , df_denom=4930, df_num=3
# ssr based chi2 test:   chi2=10.5691 , p=0.0143  , df=3
# likelihood ratio test: chi2=10.5578 , p=0.0144  , df=3
# parameter F test:         F=3.5181  , p=0.0145  , df_denom=4930, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.8988  , p=0.0207  , df_denom=4927, df_num=4
# ssr based chi2 test:   chi2=11.6164 , p=0.0204  , df=4
# likelihood ratio test: chi2=11.6028 , p=0.0206  , df=4
# parameter F test:         F=2.8988  , p=0.0207  , df_denom=4927, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1740  , p=0.3193  , df_denom=4924, df_num=5
# ssr based chi2 test:   chi2=5.8829  , p=0.3178  , df=5
# likelihood ratio test: chi2=5.8794  , p=0.3181  , df=5
# parameter F test:         F=1.1740  , p=0.3193  , df_denom=4924, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6007  , p=0.7300  , df_denom=4921, df_num=6
# ssr based chi2 test:   chi2=3.6137  , p=0.7288  , df=6
# likelihood ratio test: chi2=3.6124  , p=0.7290  , df=6
# parameter F test:         F=0.6007  , p=0.7300  , df_denom=4921, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8059  , p=0.5822  , df_denom=4918, df_num=7
# ssr based chi2 test:   chi2=5.6588  , p=0.5801  , df=7
# likelihood ratio test: chi2=5.6556  , p=0.5805  , df=7
# parameter F test:         F=0.8059  , p=0.5822  , df_denom=4918, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8044  , p=0.5987  , df_denom=4915, df_num=8
# ssr based chi2 test:   chi2=6.4572  , p=0.5962  , df=8
# likelihood ratio test: chi2=6.4530  , p=0.5966  , df=8
# parameter F test:         F=0.8044  , p=0.5987  , df_denom=4915, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9364  , p=0.4918  , df_denom=4912, df_num=9
# ssr based chi2 test:   chi2=8.4602  , p=0.4885  , df=9
# likelihood ratio test: chi2=8.4529  , p=0.4892  , df=9
# parameter F test:         F=0.9364  , p=0.4918  , df_denom=4912, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8681  , p=0.5627  , df_denom=4909, df_num=10
# ssr based chi2 test:   chi2=8.7183  , p=0.5590  , df=10
# likelihood ratio test: chi2=8.7106  , p=0.5598  , df=10
# parameter F test:         F=0.8681  , p=0.5627  , df_denom=4909, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.7930  , p=0.6474  , df_denom=4906, df_num=11
# ssr based chi2 test:   chi2=8.7644  , p=0.6436  , df=11
# likelihood ratio test: chi2=8.7566  , p=0.6443  , df=11
# parameter F test:         F=0.7930  , p=0.6474  , df_denom=4906, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.1058  , p=0.3501  , df_denom=4903, df_num=12
# ssr based chi2 test:   chi2=13.3371 , p=0.3450  , df=12
# likelihood ratio test: chi2=13.3191 , p=0.3463  , df=12
# parameter F test:         F=1.1058  , p=0.3501  , df_denom=4903, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.1429  , p=0.3167  , df_denom=4900, df_num=13
# ssr based chi2 test:   chi2=14.9395 , p=0.3111  , df=13
# likelihood ratio test: chi2=14.9169 , p=0.3126  , df=13
# parameter F test:         F=1.1429  , p=0.3167  , df_denom=4900, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.0695  , p=0.3803  , df_denom=4897, df_num=14
# ssr based chi2 test:   chi2=15.0624 , p=0.3739  , df=14
# likelihood ratio test: chi2=15.0394 , p=0.3755  , df=14
# parameter F test:         F=1.0695  , p=0.3803  , df_denom=4897, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.0502  , p=0.3990  , df_denom=4894, df_num=15
# ssr based chi2 test:   chi2=15.8523 , p=0.3919  , df=15
# likelihood ratio test: chi2=15.8269 , p=0.3937  , df=15
# parameter F test:         F=1.0502  , p=0.3990  , df_denom=4894, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.5653  , p=0.0104  , df_denom=4936, df_num=1
# ssr based chi2 test:   chi2=6.5693  , p=0.0104  , df=1
# likelihood ratio test: chi2=6.5649  , p=0.0104  , df=1
# parameter F test:         F=6.5653  , p=0.0104  , df_denom=4936, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.8078  , p=0.0030  , df_denom=4933, df_num=2
# ssr based chi2 test:   chi2=11.6274 , p=0.0030  , df=2
# likelihood ratio test: chi2=11.6138 , p=0.0030  , df=2
# parameter F test:         F=5.8078  , p=0.0030  , df_denom=4933, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.5410  , p=0.0035  , df_denom=4930, df_num=3
# ssr based chi2 test:   chi2=13.6422 , p=0.0034  , df=3
# likelihood ratio test: chi2=13.6234 , p=0.0035  , df=3
# parameter F test:         F=4.5410  , p=0.0035  , df_denom=4930, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.5165  , p=0.0395  , df_denom=4927, df_num=4
# ssr based chi2 test:   chi2=10.0843 , p=0.0390  , df=4
# likelihood ratio test: chi2=10.0740 , p=0.0392  , df=4
# parameter F test:         F=2.5165  , p=0.0395  , df_denom=4927, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9331  , p=0.4582  , df_denom=4924, df_num=5
# ssr based chi2 test:   chi2=4.6759  , p=0.4567  , df=5
# likelihood ratio test: chi2=4.6737  , p=0.4570  , df=5
# parameter F test:         F=0.9331  , p=0.4582  , df_denom=4924, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6612  , p=0.1263  , df_denom=4921, df_num=6
# ssr based chi2 test:   chi2=9.9934  , p=0.1249  , df=6
# likelihood ratio test: chi2=9.9833  , p=0.1254  , df=6
# parameter F test:         F=1.6612  , p=0.1263  , df_denom=4921, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6886  , p=0.1069  , df_denom=4918, df_num=7
# ssr based chi2 test:   chi2=11.8563 , p=0.1054  , df=7
# likelihood ratio test: chi2=11.8421 , p=0.1059  , df=7
# parameter F test:         F=1.6886  , p=0.1069  , df_denom=4918, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7641  , p=0.0792  , df_denom=4915, df_num=8
# ssr based chi2 test:   chi2=14.1614 , p=0.0777  , df=8
# likelihood ratio test: chi2=14.1412 , p=0.0782  , df=8
# parameter F test:         F=1.7641  , p=0.0792  , df_denom=4915, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6287  , p=0.1011  , df_denom=4912, df_num=9
# ssr based chi2 test:   chi2=14.7148 , p=0.0991  , df=9
# likelihood ratio test: chi2=14.6929 , p=0.0997  , df=9
# parameter F test:         F=1.6287  , p=0.1011  , df_denom=4912, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.6357  , p=0.0902  , df_denom=4909, df_num=10
# ssr based chi2 test:   chi2=16.4273 , p=0.0880  , df=10
# likelihood ratio test: chi2=16.4000 , p=0.0887  , df=10
# parameter F test:         F=1.6357  , p=0.0902  , df_denom=4909, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.5132  , p=0.1192  , df_denom=4906, df_num=11
# ssr based chi2 test:   chi2=16.7228 , p=0.1163  , df=11
# likelihood ratio test: chi2=16.6945 , p=0.1172  , df=11
# parameter F test:         F=1.5132  , p=0.1192  , df_denom=4906, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.4590  , p=0.1319  , df_denom=4903, df_num=12
# ssr based chi2 test:   chi2=17.5977 , p=0.1285  , df=12
# likelihood ratio test: chi2=17.5663 , p=0.1295  , df=12
# parameter F test:         F=1.4590  , p=0.1319  , df_denom=4903, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.3868  , p=0.1569  , df_denom=4900, df_num=13
# ssr based chi2 test:   chi2=18.1275 , p=0.1527  , df=13
# likelihood ratio test: chi2=18.0942 , p=0.1540  , df=13
# parameter F test:         F=1.3868  , p=0.1569  , df_denom=4900, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.2332  , p=0.2428  , df_denom=4897, df_num=14
# ssr based chi2 test:   chi2=17.3665 , p=0.2372  , df=14
# likelihood ratio test: chi2=17.3360 , p=0.2387  , df=14
# parameter F test:         F=1.2332  , p=0.2428  , df_denom=4897, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.1508  , p=0.3039  , df_denom=4894, df_num=15
# ssr based chi2 test:   chi2=17.3716 , p=0.2971  , df=15
# likelihood ratio test: chi2=17.3411 , p=0.2989  , df=15
# parameter F test:         F=1.1508  , p=0.3039  , df_denom=4894, df_num=15

# %%
Granger = pd.DataFrame(columns = ['windowSize (ms)', 'Modo', 'Direction', 'Lag', 'Chi2', 'p'])
timeSeriesM = pd.read_csv(filesPath[2])
timeSeriesS = pd.read_csv(filesPath[3])
Z1 = timeSeriesM[['Pulse X', 'Pulse Y']].to_numpy(dtype = bool)
Z2 = timeSeriesM[['Pulse Y', 'Pulse X']].to_numpy(dtype = bool)
Z3 = timeSeriesS[['Pulse X', 'Pulse Y']].to_numpy(dtype = bool)
Z4 = timeSeriesS[['Pulse Y', 'Pulse X']].to_numpy(dtype = bool)
result1 = stats.grangercausalitytests(Z1, 15, addconst=True, verbose=True)
result2 = stats.grangercausalitytests(Z2, 15, addconst=True, verbose=True)
result3 = stats.grangercausalitytests(Z3, 15, addconst=True, verbose=True)
result4 = stats.grangercausalitytests(Z4, 15, addconst=True, verbose=True)

for i in range(7, 15):
    delaySon = i + 1
    ssr_ftest = result1[delaySon][0]['ssr_ftest']
    ssr_qtest = result1[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'C->D', 'Modo': 'M', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    ssr_ftest = result3[delaySon][0]['ssr_ftest']
    ssr_qtest = result3[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'C->D', 'Modo': 'S', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    ssr_ftest = result2[delaySon][0]['ssr_ftest']
    ssr_qtest = result2[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'D->C', 'Modo': 'M', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])

    ssr_ftest = result4[delaySon][0]['ssr_ftest']
    ssr_qtest = result4[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'D->C', 'Modo': 'S', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])

Granger2 = Granger.copy()
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.2070  , p=0.0734  , df_denom=5542, df_num=1
# ssr based chi2 test:   chi2=3.2087  , p=0.0732  , df=1
# likelihood ratio test: chi2=3.2078  , p=0.0733  , df=1
# parameter F test:         F=3.2070  , p=0.0734  , df_denom=5542, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9361  , p=0.1444  , df_denom=5539, df_num=2
# ssr based chi2 test:   chi2=3.8756  , p=0.1440  , df=2
# likelihood ratio test: chi2=3.8743  , p=0.1441  , df=2
# parameter F test:         F=1.9361  , p=0.1444  , df_denom=5539, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4216  , p=0.2344  , df_denom=5536, df_num=3
# ssr based chi2 test:   chi2=4.2703  , p=0.2337  , df=3
# likelihood ratio test: chi2=4.2687  , p=0.2339  , df=3
# parameter F test:         F=1.4216  , p=0.2344  , df_denom=5536, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0275  , p=0.3914  , df_denom=5533, df_num=4
# ssr based chi2 test:   chi2=4.1169  , p=0.3904  , df=4
# likelihood ratio test: chi2=4.1153  , p=0.3906  , df=4
# parameter F test:         F=1.0275  , p=0.3914  , df_denom=5533, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6484  , p=0.6628  , df_denom=5530, df_num=5
# ssr based chi2 test:   chi2=3.2483  , p=0.6618  , df=5
# likelihood ratio test: chi2=3.2474  , p=0.6619  , df=5
# parameter F test:         F=0.6484  , p=0.6628  , df_denom=5530, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0206  , p=0.4096  , df_denom=5527, df_num=6
# ssr based chi2 test:   chi2=6.1382  , p=0.4079  , df=6
# likelihood ratio test: chi2=6.1348  , p=0.4083  , df=6
# parameter F test:         F=1.0206  , p=0.4096  , df_denom=5527, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2553  , p=0.0273  , df_denom=5524, df_num=7
# ssr based chi2 test:   chi2=15.8301 , p=0.0267  , df=7
# likelihood ratio test: chi2=15.8075 , p=0.0269  , df=7
# parameter F test:         F=2.2553  , p=0.0273  , df_denom=5524, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.0604  , p=0.0362  , df_denom=5521, df_num=8
# ssr based chi2 test:   chi2=16.5338 , p=0.0353  , df=8
# likelihood ratio test: chi2=16.5092 , p=0.0356  , df=8
# parameter F test:         F=2.0604  , p=0.0362  , df_denom=5521, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9020  , p=0.0471  , df_denom=5518, df_num=9
# ssr based chi2 test:   chi2=17.1768 , p=0.0460  , df=9
# likelihood ratio test: chi2=17.1502 , p=0.0464  , df=9
# parameter F test:         F=1.9020  , p=0.0471  , df_denom=5518, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9734  , p=0.0321  , df_denom=5515, df_num=10
# ssr based chi2 test:   chi2=19.8093 , p=0.0311  , df=10
# likelihood ratio test: chi2=19.7739 , p=0.0315  , df=10
# parameter F test:         F=1.9734  , p=0.0321  , df_denom=5515, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.8001  , p=0.0484  , df_denom=5512, df_num=11
# ssr based chi2 test:   chi2=19.8837 , p=0.0470  , df=11
# likelihood ratio test: chi2=19.8481 , p=0.0475  , df=11
# parameter F test:         F=1.8001  , p=0.0484  , df_denom=5512, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.6520  , p=0.0708  , df_denom=5509, df_num=12
# ssr based chi2 test:   chi2=19.9145 , p=0.0687  , df=12
# likelihood ratio test: chi2=19.8788 , p=0.0694  , df=12
# parameter F test:         F=1.6520  , p=0.0708  , df_denom=5509, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.5309  , p=0.0981  , df_denom=5506, df_num=13
# ssr based chi2 test:   chi2=19.9993 , p=0.0952  , df=13
# likelihood ratio test: chi2=19.9633 , p=0.0961  , df=13
# parameter F test:         F=1.5309  , p=0.0981  , df_denom=5506, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.4912  , p=0.1053  , df_denom=5503, df_num=14
# ssr based chi2 test:   chi2=20.9872 , p=0.1020  , df=14
# likelihood ratio test: chi2=20.9475 , p=0.1030  , df=14
# parameter F test:         F=1.4912  , p=0.1053  , df_denom=5503, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.4987  , p=0.0963  , df_denom=5500, df_num=15
# ssr based chi2 test:   chi2=22.6072 , p=0.0928  , df=15
# likelihood ratio test: chi2=22.5611 , p=0.0939  , df=15
# parameter F test:         F=1.4987  , p=0.0963  , df_denom=5500, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0738  , p=0.7860  , df_denom=5542, df_num=1
# ssr based chi2 test:   chi2=0.0738  , p=0.7859  , df=1
# likelihood ratio test: chi2=0.0738  , p=0.7859  , df=1
# parameter F test:         F=0.0738  , p=0.7860  , df_denom=5542, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2564  , p=0.7738  , df_denom=5539, df_num=2
# ssr based chi2 test:   chi2=0.5134  , p=0.7736  , df=2
# likelihood ratio test: chi2=0.5133  , p=0.7736  , df=2
# parameter F test:         F=0.2564  , p=0.7738  , df_denom=5539, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4032  , p=0.7507  , df_denom=5536, df_num=3
# ssr based chi2 test:   chi2=1.2111  , p=0.7503  , df=3
# likelihood ratio test: chi2=1.2109  , p=0.7504  , df=3
# parameter F test:         F=0.4032  , p=0.7507  , df_denom=5536, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7378  , p=0.5661  , df_denom=5533, df_num=4
# ssr based chi2 test:   chi2=2.9559  , p=0.5652  , df=4
# likelihood ratio test: chi2=2.9551  , p=0.5654  , df=4
# parameter F test:         F=0.7378  , p=0.5661  , df_denom=5533, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6052  , p=0.6959  , df_denom=5530, df_num=5
# ssr based chi2 test:   chi2=3.0322  , p=0.6950  , df=5
# likelihood ratio test: chi2=3.0314  , p=0.6951  , df=5
# parameter F test:         F=0.6052  , p=0.6959  , df_denom=5530, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5898  , p=0.7388  , df_denom=5527, df_num=6
# ssr based chi2 test:   chi2=3.5468  , p=0.7377  , df=6
# likelihood ratio test: chi2=3.5457  , p=0.7379  , df=6
# parameter F test:         F=0.5898  , p=0.7388  , df_denom=5527, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2068  , p=0.2950  , df_denom=5524, df_num=7
# ssr based chi2 test:   chi2=8.4705  , p=0.2929  , df=7
# likelihood ratio test: chi2=8.4640  , p=0.2935  , df=7
# parameter F test:         F=1.2068  , p=0.2950  , df_denom=5524, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1203  , p=0.3457  , df_denom=5521, df_num=8
# ssr based chi2 test:   chi2=8.9902  , p=0.3431  , df=8
# likelihood ratio test: chi2=8.9829  , p=0.3437  , df=8
# parameter F test:         F=1.1203  , p=0.3457  , df_denom=5521, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9964  , p=0.4404  , df_denom=5518, df_num=9
# ssr based chi2 test:   chi2=8.9985  , p=0.4374  , df=9
# likelihood ratio test: chi2=8.9912  , p=0.4381  , df=9
# parameter F test:         F=0.9964  , p=0.4404  , df_denom=5518, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2698  , p=0.2414  , df_denom=5515, df_num=10
# ssr based chi2 test:   chi2=12.7460 , p=0.2382  , df=10
# likelihood ratio test: chi2=12.7313 , p=0.2391  , df=10
# parameter F test:         F=1.2698  , p=0.2414  , df_denom=5515, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.1797  , p=0.2951  , df_denom=5512, df_num=11
# ssr based chi2 test:   chi2=13.0311 , p=0.2913  , df=11
# likelihood ratio test: chi2=13.0158 , p=0.2923  , df=11
# parameter F test:         F=1.1797  , p=0.2951  , df_denom=5512, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.2706  , p=0.2286  , df_denom=5509, df_num=12
# ssr based chi2 test:   chi2=15.3163 , p=0.2246  , df=12
# likelihood ratio test: chi2=15.2951 , p=0.2257  , df=12
# parameter F test:         F=1.2706  , p=0.2286  , df_denom=5509, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.1761  , p=0.2900  , df_denom=5506, df_num=13
# ssr based chi2 test:   chi2=15.3639 , p=0.2852  , df=13
# likelihood ratio test: chi2=15.3426 , p=0.2865  , df=13
# parameter F test:         F=1.1761  , p=0.2900  , df_denom=5506, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.2422  , p=0.2364  , df_denom=5503, df_num=14
# ssr based chi2 test:   chi2=17.4821 , p=0.2314  , df=14
# likelihood ratio test: chi2=17.4546 , p=0.2328  , df=14
# parameter F test:         F=1.2422  , p=0.2364  , df_denom=5503, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.4402  , p=0.1191  , df_denom=5500, df_num=15
# ssr based chi2 test:   chi2=21.7242 , p=0.1152  , df=15
# likelihood ratio test: chi2=21.6816 , p=0.1164  , df=15
# parameter F test:         F=1.4402  , p=0.1191  , df_denom=5500, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0037  , p=0.1570  , df_denom=5477, df_num=1
# ssr based chi2 test:   chi2=2.0048  , p=0.1568  , df=1
# likelihood ratio test: chi2=2.0045  , p=0.1568  , df=1
# parameter F test:         F=2.0037  , p=0.1570  , df_denom=5477, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5213  , p=0.2185  , df_denom=5474, df_num=2
# ssr based chi2 test:   chi2=3.0455  , p=0.2181  , df=2
# likelihood ratio test: chi2=3.0446  , p=0.2182  , df=2
# parameter F test:         F=1.5213  , p=0.2185  , df_denom=5474, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1479  , p=0.3282  , df_denom=5471, df_num=3
# ssr based chi2 test:   chi2=3.4481  , p=0.3276  , df=3
# likelihood ratio test: chi2=3.4470  , p=0.3277  , df=3
# parameter F test:         F=1.1479  , p=0.3282  , df_denom=5471, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5510  , p=0.6983  , df_denom=5468, df_num=4
# ssr based chi2 test:   chi2=2.2078  , p=0.6976  , df=4
# likelihood ratio test: chi2=2.2073  , p=0.6977  , df=4
# parameter F test:         F=0.5510  , p=0.6983  , df_denom=5468, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1775  , p=0.3175  , df_denom=5465, df_num=5
# ssr based chi2 test:   chi2=5.8994  , p=0.3161  , df=5
# likelihood ratio test: chi2=5.8962  , p=0.3165  , df=5
# parameter F test:         F=1.1775  , p=0.3175  , df_denom=5465, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9436  , p=0.4622  , df_denom=5462, df_num=6
# ssr based chi2 test:   chi2=5.6751  , p=0.4606  , df=6
# likelihood ratio test: chi2=5.6721  , p=0.4609  , df=6
# parameter F test:         F=0.9436  , p=0.4622  , df_denom=5462, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9578  , p=0.4604  , df_denom=5459, df_num=7
# ssr based chi2 test:   chi2=6.7230  , p=0.4583  , df=7
# likelihood ratio test: chi2=6.7189  , p=0.4587  , df=7
# parameter F test:         F=0.9578  , p=0.4604  , df_denom=5459, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8779  , p=0.5342  , df_denom=5456, df_num=8
# ssr based chi2 test:   chi2=7.0450  , p=0.5318  , df=8
# likelihood ratio test: chi2=7.0404  , p=0.5323  , df=8
# parameter F test:         F=0.8779  , p=0.5342  , df_denom=5456, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8165  , p=0.6009  , df_denom=5453, df_num=9
# ssr based chi2 test:   chi2=7.3741  , p=0.5982  , df=9
# likelihood ratio test: chi2=7.3691  , p=0.5987  , df=9
# parameter F test:         F=0.8165  , p=0.6009  , df_denom=5453, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.5550  , p=0.1136  , df_denom=5450, df_num=10
# ssr based chi2 test:   chi2=15.6100 , p=0.1114  , df=10
# likelihood ratio test: chi2=15.5878 , p=0.1121  , df=10
# parameter F test:         F=1.5550  , p=0.1136  , df_denom=5450, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.4280  , p=0.1527  , df_denom=5447, df_num=11
# ssr based chi2 test:   chi2=15.7739 , p=0.1497  , df=11
# likelihood ratio test: chi2=15.7512 , p=0.1506  , df=11
# parameter F test:         F=1.4280  , p=0.1527  , df_denom=5447, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.3051  , p=0.2076  , df_denom=5444, df_num=12
# ssr based chi2 test:   chi2=15.7333 , p=0.2038  , df=12
# likelihood ratio test: chi2=15.7107 , p=0.2048  , df=12
# parameter F test:         F=1.3051  , p=0.2076  , df_denom=5444, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.1982  , p=0.2732  , df_denom=5441, df_num=13
# ssr based chi2 test:   chi2=15.6535 , p=0.2683  , df=13
# likelihood ratio test: chi2=15.6311 , p=0.2696  , df=13
# parameter F test:         F=1.1982  , p=0.2732  , df_denom=5441, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.1672  , p=0.2933  , df_denom=5438, df_num=14
# ssr based chi2 test:   chi2=16.4286 , p=0.2879  , df=14
# likelihood ratio test: chi2=16.4040 , p=0.2893  , df=14
# parameter F test:         F=1.1672  , p=0.2933  , df_denom=5438, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.1369  , p=0.3160  , df_denom=5435, df_num=15
# ssr based chi2 test:   chi2=17.1513 , p=0.3099  , df=15
# likelihood ratio test: chi2=17.1245 , p=0.3115  , df=15
# parameter F test:         F=1.1369  , p=0.3160  , df_denom=5435, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1209  , p=0.7281  , df_denom=5477, df_num=1
# ssr based chi2 test:   chi2=0.1210  , p=0.7280  , df=1
# likelihood ratio test: chi2=0.1210  , p=0.7280  , df=1
# parameter F test:         F=0.1209  , p=0.7281  , df_denom=5477, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3258  , p=0.7220  , df_denom=5474, df_num=2
# ssr based chi2 test:   chi2=0.6521  , p=0.7218  , df=2
# likelihood ratio test: chi2=0.6521  , p=0.7218  , df=2
# parameter F test:         F=0.3258  , p=0.7220  , df_denom=5474, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4572  , p=0.7122  , df_denom=5471, df_num=3
# ssr based chi2 test:   chi2=1.3734  , p=0.7118  , df=3
# likelihood ratio test: chi2=1.3732  , p=0.7118  , df=3
# parameter F test:         F=0.4572  , p=0.7122  , df_denom=5471, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1574  , p=0.9597  , df_denom=5468, df_num=4
# ssr based chi2 test:   chi2=0.6308  , p=0.9596  , df=4
# likelihood ratio test: chi2=0.6307  , p=0.9596  , df=4
# parameter F test:         F=0.1574  , p=0.9597  , df_denom=5468, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3442  , p=0.8862  , df_denom=5465, df_num=5
# ssr based chi2 test:   chi2=1.7244  , p=0.8858  , df=5
# likelihood ratio test: chi2=1.7242  , p=0.8858  , df=5
# parameter F test:         F=0.3442  , p=0.8862  , df_denom=5465, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8924  , p=0.4993  , df_denom=5462, df_num=6
# ssr based chi2 test:   chi2=5.3671  , p=0.4977  , df=6
# likelihood ratio test: chi2=5.3645  , p=0.4980  , df=6
# parameter F test:         F=0.8924  , p=0.4993  , df_denom=5462, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5266  , p=0.8151  , df_denom=5459, df_num=7
# ssr based chi2 test:   chi2=3.6961  , p=0.8140  , df=7
# likelihood ratio test: chi2=3.6949  , p=0.8142  , df=7
# parameter F test:         F=0.5266  , p=0.8151  , df_denom=5459, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6091  , p=0.7711  , df_denom=5456, df_num=8
# ssr based chi2 test:   chi2=4.8877  , p=0.7695  , df=8
# likelihood ratio test: chi2=4.8855  , p=0.7697  , df=8
# parameter F test:         F=0.6091  , p=0.7711  , df_denom=5456, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5520  , p=0.8370  , df_denom=5453, df_num=9
# ssr based chi2 test:   chi2=4.9850  , p=0.8356  , df=9
# likelihood ratio test: chi2=4.9827  , p=0.8358  , df=9
# parameter F test:         F=0.5520  , p=0.8370  , df_denom=5453, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5635  , p=0.8449  , df_denom=5450, df_num=10
# ssr based chi2 test:   chi2=5.6564  , p=0.8433  , df=10
# likelihood ratio test: chi2=5.6535  , p=0.8435  , df=10
# parameter F test:         F=0.5635  , p=0.8449  , df_denom=5450, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.6735  , p=0.7651  , df_denom=5447, df_num=11
# ssr based chi2 test:   chi2=7.4392  , p=0.7625  , df=11
# likelihood ratio test: chi2=7.4342  , p=0.7629  , df=11
# parameter F test:         F=0.6735  , p=0.7651  , df_denom=5447, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7226  , p=0.7306  , df_denom=5444, df_num=12
# ssr based chi2 test:   chi2=8.7111  , p=0.7274  , df=12
# likelihood ratio test: chi2=8.7042  , p=0.7280  , df=12
# parameter F test:         F=0.7226  , p=0.7306  , df_denom=5444, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.7545  , p=0.7095  , df_denom=5441, df_num=13
# ssr based chi2 test:   chi2=9.8566  , p=0.7056  , df=13
# likelihood ratio test: chi2=9.8477  , p=0.7063  , df=13
# parameter F test:         F=0.7545  , p=0.7095  , df_denom=5441, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.7198  , p=0.7564  , df_denom=5438, df_num=14
# ssr based chi2 test:   chi2=10.1307 , p=0.7526  , df=14
# likelihood ratio test: chi2=10.1213 , p=0.7533  , df=14
# parameter F test:         F=0.7198  , p=0.7564  , df_denom=5438, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.7040  , p=0.7830  , df_denom=5435, df_num=15
# ssr based chi2 test:   chi2=10.6200 , p=0.7790  , df=15
# likelihood ratio test: chi2=10.6097 , p=0.7797  , df=15
# parameter F test:         F=0.7040  , p=0.7830  , df_denom=5435, df_num=15

# %%
Granger = pd.DataFrame(columns = ['windowSize (ms)', 'Modo', 'Direction', 'Lag', 'Chi2', 'p'])
timeSeriesM = pd.read_csv(filesPath[4])
timeSeriesS = pd.read_csv(filesPath[5])
Z1 = timeSeriesM[['Pulse X', 'Pulse Y']].to_numpy(dtype = bool)
Z2 = timeSeriesM[['Pulse Y', 'Pulse X']].to_numpy(dtype = bool)
Z3 = timeSeriesS[['Pulse X', 'Pulse Y']].to_numpy(dtype = bool)
Z4 = timeSeriesS[['Pulse Y', 'Pulse X']].to_numpy(dtype = bool)
result1 = stats.grangercausalitytests(Z1, 15, addconst=True, verbose=True)
result2 = stats.grangercausalitytests(Z2, 15, addconst=True, verbose=True)
result3 = stats.grangercausalitytests(Z3, 15, addconst=True, verbose=True)
result4 = stats.grangercausalitytests(Z4, 15, addconst=True, verbose=True)

for i in range(7, 15):
    delaySon = i + 1
    ssr_ftest = result1[delaySon][0]['ssr_ftest']
    ssr_qtest = result1[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'E->F', 'Modo': 'M', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    ssr_ftest = result3[delaySon][0]['ssr_ftest']
    ssr_qtest = result3[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'E->F', 'Modo': 'S', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    ssr_ftest = result2[delaySon][0]['ssr_ftest']
    ssr_qtest = result2[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'F->E', 'Modo': 'M', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])

    ssr_ftest = result4[delaySon][0]['ssr_ftest']
    ssr_qtest = result4[delaySon][0]['ssr_chi2test']
    f = ssr_ftest[0]
    p = ssr_ftest[1]
    q = ssr_qtest[0]
    Granger = Granger.append([{'Direction' : 'F->E', 'Modo': 'S', 'windowSize (ms)' : 100, 'Lag' : delaySon, 'Chi2': q, 'p' : p}])
    
Granger3 = Granger.copy()
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.4868  , p=0.0619  , df_denom=5552, df_num=1
# ssr based chi2 test:   chi2=3.4886  , p=0.0618  , df=1
# likelihood ratio test: chi2=3.4875  , p=0.0618  , df=1
# parameter F test:         F=3.4868  , p=0.0619  , df_denom=5552, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=8.4535  , p=0.0002  , df_denom=5549, df_num=2
# ssr based chi2 test:   chi2=16.9222 , p=0.0002  , df=2
# likelihood ratio test: chi2=16.8964 , p=0.0002  , df=2
# parameter F test:         F=8.4535  , p=0.0002  , df_denom=5549, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=9.2258  , p=0.0000  , df_denom=5546, df_num=3
# ssr based chi2 test:   chi2=27.7124 , p=0.0000  , df=3
# likelihood ratio test: chi2=27.6435 , p=0.0000  , df=3
# parameter F test:         F=9.2258  , p=0.0000  , df_denom=5546, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=10.6105 , p=0.0000  , df_denom=5543, df_num=4
# ssr based chi2 test:   chi2=42.5111 , p=0.0000  , df=4
# likelihood ratio test: chi2=42.3491 , p=0.0000  , df=4
# parameter F test:         F=10.6105 , p=0.0000  , df_denom=5543, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=6.1368  , p=0.0000  , df_denom=5540, df_num=5
# ssr based chi2 test:   chi2=30.7452 , p=0.0000  , df=5
# likelihood ratio test: chi2=30.6603 , p=0.0000  , df=5
# parameter F test:         F=6.1368  , p=0.0000  , df_denom=5540, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.0911  , p=0.0051  , df_denom=5537, df_num=6
# ssr based chi2 test:   chi2=18.5903 , p=0.0049  , df=6
# likelihood ratio test: chi2=18.5593 , p=0.0050  , df=6
# parameter F test:         F=3.0911  , p=0.0051  , df_denom=5537, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5846  , p=0.1349  , df_denom=5534, df_num=7
# ssr based chi2 test:   chi2=11.1221 , p=0.1334  , df=7
# likelihood ratio test: chi2=11.1110 , p=0.1339  , df=7
# parameter F test:         F=1.5846  , p=0.1349  , df_denom=5534, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.4105  , p=0.0135  , df_denom=5531, df_num=8
# ssr based chi2 test:   chi2=19.3436 , p=0.0131  , df=8
# likelihood ratio test: chi2=19.3100 , p=0.0133  , df=8
# parameter F test:         F=2.4105  , p=0.0135  , df_denom=5531, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.1998  , p=0.0194  , df_denom=5528, df_num=9
# ssr based chi2 test:   chi2=19.8659 , p=0.0188  , df=9
# likelihood ratio test: chi2=19.8304 , p=0.0190  , df=9
# parameter F test:         F=2.1998  , p=0.0194  , df_denom=5528, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.3155  , p=0.0103  , df_denom=5525, df_num=10
# ssr based chi2 test:   chi2=23.2432 , p=0.0099  , df=10
# likelihood ratio test: chi2=23.1946 , p=0.0101  , df=10
# parameter F test:         F=2.3155  , p=0.0103  , df_denom=5525, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.2022  , p=0.0120  , df_denom=5522, df_num=11
# ssr based chi2 test:   chi2=24.3250 , p=0.0114  , df=11
# likelihood ratio test: chi2=24.2718 , p=0.0116  , df=11
# parameter F test:         F=2.2022  , p=0.0120  , df_denom=5522, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.0548  , p=0.0167  , df_denom=5519, df_num=12
# ssr based chi2 test:   chi2=24.7691 , p=0.0160  , df=12
# likelihood ratio test: chi2=24.7139 , p=0.0162  , df=12
# parameter F test:         F=2.0548  , p=0.0167  , df_denom=5519, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.0138  , p=0.0163  , df_denom=5516, df_num=13
# ssr based chi2 test:   chi2=26.3076 , p=0.0155  , df=13
# likelihood ratio test: chi2=26.2453 , p=0.0158  , df=13
# parameter F test:         F=2.0138  , p=0.0163  , df_denom=5516, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.8967  , p=0.0222  , df_denom=5513, df_num=14
# ssr based chi2 test:   chi2=26.6939 , p=0.0211  , df=14
# likelihood ratio test: chi2=26.6299 , p=0.0215  , df=14
# parameter F test:         F=1.8967  , p=0.0222  , df_denom=5513, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.9554  , p=0.0148  , df_denom=5510, df_num=15
# ssr based chi2 test:   chi2=29.4960 , p=0.0139  , df=15
# likelihood ratio test: chi2=29.4178 , p=0.0142  , df=15
# parameter F test:         F=1.9554  , p=0.0148  , df_denom=5510, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3610  , p=0.2434  , df_denom=5552, df_num=1
# ssr based chi2 test:   chi2=1.3618  , p=0.2432  , df=1
# likelihood ratio test: chi2=1.3616  , p=0.2433  , df=1
# parameter F test:         F=1.3610  , p=0.2434  , df_denom=5552, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.1815  , p=0.0021  , df_denom=5549, df_num=2
# ssr based chi2 test:   chi2=12.3742 , p=0.0021  , df=2
# likelihood ratio test: chi2=12.3604 , p=0.0021  , df=2
# parameter F test:         F=6.1815  , p=0.0021  , df_denom=5549, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=15.0496 , p=0.0000  , df_denom=5546, df_num=3
# ssr based chi2 test:   chi2=45.2057 , p=0.0000  , df=3
# likelihood ratio test: chi2=45.0227 , p=0.0000  , df=3
# parameter F test:         F=15.0496 , p=0.0000  , df_denom=5546, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=10.2582 , p=0.0000  , df_denom=5543, df_num=4
# ssr based chi2 test:   chi2=41.0995 , p=0.0000  , df=4
# likelihood ratio test: chi2=40.9482 , p=0.0000  , df=4
# parameter F test:         F=10.2582 , p=0.0000  , df_denom=5543, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=6.0911  , p=0.0000  , df_denom=5540, df_num=5
# ssr based chi2 test:   chi2=30.5159 , p=0.0000  , df=5
# likelihood ratio test: chi2=30.4323 , p=0.0000  , df=5
# parameter F test:         F=6.0911  , p=0.0000  , df_denom=5540, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.3167  , p=0.0029  , df_denom=5537, df_num=6
# ssr based chi2 test:   chi2=19.9472 , p=0.0028  , df=6
# likelihood ratio test: chi2=19.9115 , p=0.0029  , df=6
# parameter F test:         F=3.3167  , p=0.0029  , df_denom=5537, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9864  , p=0.4390  , df_denom=5534, df_num=7
# ssr based chi2 test:   chi2=6.9237  , p=0.4369  , df=7
# likelihood ratio test: chi2=6.9193  , p=0.4373  , df=7
# parameter F test:         F=0.9864  , p=0.4390  , df_denom=5534, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8630  , p=0.5471  , df_denom=5531, df_num=8
# ssr based chi2 test:   chi2=6.9250  , p=0.5448  , df=8
# likelihood ratio test: chi2=6.9206  , p=0.5452  , df=8
# parameter F test:         F=0.8630  , p=0.5471  , df_denom=5531, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7720  , p=0.6426  , df_denom=5528, df_num=9
# ssr based chi2 test:   chi2=6.9717  , p=0.6401  , df=9
# likelihood ratio test: chi2=6.9673  , p=0.6405  , df=9
# parameter F test:         F=0.7720  , p=0.6426  , df_denom=5528, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1700  , p=0.3059  , df_denom=5525, df_num=10
# ssr based chi2 test:   chi2=11.7447 , p=0.3025  , df=10
# likelihood ratio test: chi2=11.7323 , p=0.3034  , df=10
# parameter F test:         F=1.1700  , p=0.3059  , df_denom=5525, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0713  , p=0.3803  , df_denom=5522, df_num=11
# ssr based chi2 test:   chi2=11.8329 , p=0.3763  , df=11
# likelihood ratio test: chi2=11.8203 , p=0.3773  , df=11
# parameter F test:         F=1.0713  , p=0.3803  , df_denom=5522, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.9820  , p=0.4634  , df_denom=5519, df_num=12
# ssr based chi2 test:   chi2=11.8372 , p=0.4588  , df=12
# likelihood ratio test: chi2=11.8246 , p=0.4599  , df=12
# parameter F test:         F=0.9820  , p=0.4634  , df_denom=5519, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.8903  , p=0.5629  , df_denom=5516, df_num=13
# ssr based chi2 test:   chi2=11.6308 , p=0.5581  , df=13
# likelihood ratio test: chi2=11.6186 , p=0.5591  , df=13
# parameter F test:         F=0.8903  , p=0.5629  , df_denom=5516, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.8995  , p=0.5589  , df_denom=5513, df_num=14
# ssr based chi2 test:   chi2=12.6586 , p=0.5536  , df=14
# likelihood ratio test: chi2=12.6442 , p=0.5547  , df=14
# parameter F test:         F=0.8995  , p=0.5589  , df_denom=5513, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.8653  , p=0.6039  , df_denom=5510, df_num=15
# ssr based chi2 test:   chi2=13.0519 , p=0.5983  , df=15
# likelihood ratio test: chi2=13.0365 , p=0.5995  , df=15
# parameter F test:         F=0.8653  , p=0.6039  , df_denom=5510, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9560  , p=0.0857  , df_denom=1660, df_num=1
# ssr based chi2 test:   chi2=2.9614  , p=0.0853  , df=1
# likelihood ratio test: chi2=2.9587  , p=0.0854  , df=1
# parameter F test:         F=2.9560  , p=0.0857  , df_denom=1660, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6171  , p=0.1988  , df_denom=1657, df_num=2
# ssr based chi2 test:   chi2=3.2439  , p=0.1975  , df=2
# likelihood ratio test: chi2=3.2408  , p=0.1978  , df=2
# parameter F test:         F=1.6171  , p=0.1988  , df_denom=1657, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1349  , p=0.3337  , df_denom=1654, df_num=3
# ssr based chi2 test:   chi2=3.4191  , p=0.3314  , df=3
# likelihood ratio test: chi2=3.4155  , p=0.3319  , df=3
# parameter F test:         F=1.1349  , p=0.3337  , df_denom=1654, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0232  , p=0.3940  , df_denom=1651, df_num=4
# ssr based chi2 test:   chi2=4.1150  , p=0.3907  , df=4
# likelihood ratio test: chi2=4.1099  , p=0.3913  , df=4
# parameter F test:         F=1.0232  , p=0.3940  , df_denom=1651, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7898  , p=0.5569  , df_denom=1648, df_num=5
# ssr based chi2 test:   chi2=3.9753  , p=0.5530  , df=5
# likelihood ratio test: chi2=3.9706  , p=0.5537  , df=5
# parameter F test:         F=0.7898  , p=0.5569  , df_denom=1648, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9520  , p=0.4566  , df_denom=1645, df_num=6
# ssr based chi2 test:   chi2=5.7570  , p=0.4510  , df=6
# likelihood ratio test: chi2=5.7471  , p=0.4521  , df=6
# parameter F test:         F=0.9520  , p=0.4566  , df_denom=1645, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8928  , p=0.5112  , df_denom=1642, df_num=7
# ssr based chi2 test:   chi2=6.3065  , p=0.5045  , df=7
# likelihood ratio test: chi2=6.2945  , p=0.5058  , df=7
# parameter F test:         F=0.8928  , p=0.5112  , df_denom=1642, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7861  , p=0.6150  , df_denom=1639, df_num=8
# ssr based chi2 test:   chi2=6.3542  , p=0.6076  , df=8
# likelihood ratio test: chi2=6.3420  , p=0.6090  , df=8
# parameter F test:         F=0.7861  , p=0.6150  , df_denom=1639, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7619  , p=0.6519  , df_denom=1636, df_num=9
# ssr based chi2 test:   chi2=6.9371  , p=0.6437  , df=9
# likelihood ratio test: chi2=6.9226  , p=0.6452  , df=9
# parameter F test:         F=0.7619  , p=0.6519  , df_denom=1636, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7545  , p=0.6731  , df_denom=1633, df_num=10
# ssr based chi2 test:   chi2=7.6422  , p=0.6637  , df=10
# likelihood ratio test: chi2=7.6246  , p=0.6655  , df=10
# parameter F test:         F=0.7545  , p=0.6731  , df_denom=1633, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.6923  , p=0.7470  , df_denom=1630, df_num=11
# ssr based chi2 test:   chi2=7.7233  , p=0.7379  , df=11
# likelihood ratio test: chi2=7.7053  , p=0.7394  , df=11
# parameter F test:         F=0.6923  , p=0.7470  , df_denom=1630, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.6574  , p=0.7934  , df_denom=1627, df_num=12
# ssr based chi2 test:   chi2=8.0101  , p=0.7843  , df=12
# likelihood ratio test: chi2=7.9908  , p=0.7859  , df=12
# parameter F test:         F=0.6574  , p=0.7934  , df_denom=1627, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.6545  , p=0.8085  , df_denom=1624, df_num=13
# ssr based chi2 test:   chi2=8.6503  , p=0.7988  , df=13
# likelihood ratio test: chi2=8.6277  , p=0.8004  , df=13
# parameter F test:         F=0.6545  , p=0.8085  , df_denom=1624, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.9253  , p=0.5304  , df_denom=1621, df_num=14
# ssr based chi2 test:   chi2=13.1860 , p=0.5119  , df=14
# likelihood ratio test: chi2=13.1336 , p=0.5160  , df=14
# parameter F test:         F=0.9253  , p=0.5304  , df_denom=1621, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.9140  , p=0.5479  , df_denom=1618, df_num=15
# ssr based chi2 test:   chi2=13.9720 , p=0.5277  , df=15
# likelihood ratio test: chi2=13.9131 , p=0.5321  , df=15
# parameter F test:         F=0.9140  , p=0.5479  , df_denom=1618, df_num=15
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0003  , p=0.9874  , df_denom=1660, df_num=1
# ssr based chi2 test:   chi2=0.0003  , p=0.9873  , df=1
# likelihood ratio test: chi2=0.0003  , p=0.9873  , df=1
# parameter F test:         F=0.0003  , p=0.9874  , df_denom=1660, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1347  , p=0.8740  , df_denom=1657, df_num=2
# ssr based chi2 test:   chi2=0.2703  , p=0.8736  , df=2
# likelihood ratio test: chi2=0.2702  , p=0.8736  , df=2
# parameter F test:         F=0.1347  , p=0.8740  , df_denom=1657, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0369  , p=0.9905  , df_denom=1654, df_num=3
# ssr based chi2 test:   chi2=0.1112  , p=0.9905  , df=3
# likelihood ratio test: chi2=0.1112  , p=0.9905  , df=3
# parameter F test:         F=0.0369  , p=0.9905  , df_denom=1654, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4461  , p=0.7753  , df_denom=1651, df_num=4
# ssr based chi2 test:   chi2=1.7940  , p=0.7736  , df=4
# likelihood ratio test: chi2=1.7931  , p=0.7738  , df=4
# parameter F test:         F=0.4461  , p=0.7753  , df_denom=1651, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3892  , p=0.8565  , df_denom=1648, df_num=5
# ssr based chi2 test:   chi2=1.9587  , p=0.8548  , df=5
# likelihood ratio test: chi2=1.9576  , p=0.8550  , df=5
# parameter F test:         F=0.3892  , p=0.8565  , df_denom=1648, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4898  , p=0.8164  , df_denom=1645, df_num=6
# ssr based chi2 test:   chi2=2.9619  , p=0.8136  , df=6
# likelihood ratio test: chi2=2.9592  , p=0.8139  , df=6
# parameter F test:         F=0.4898  , p=0.8164  , df_denom=1645, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.3391  , p=0.9362  , df_denom=1642, df_num=7
# ssr based chi2 test:   chi2=2.3957  , p=0.9347  , df=7
# likelihood ratio test: chi2=2.3939  , p=0.9349  , df=7
# parameter F test:         F=0.3391  , p=0.9362  , df_denom=1642, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.3274  , p=0.9558  , df_denom=1639, df_num=8
# ssr based chi2 test:   chi2=2.6466  , p=0.9545  , df=8
# likelihood ratio test: chi2=2.6445  , p=0.9547  , df=8
# parameter F test:         F=0.3274  , p=0.9558  , df_denom=1639, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5171  , p=0.8631  , df_denom=1636, df_num=9
# ssr based chi2 test:   chi2=4.7083  , p=0.8590  , df=9
# likelihood ratio test: chi2=4.7016  , p=0.8595  , df=9
# parameter F test:         F=0.5171  , p=0.8631  , df_denom=1636, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6854  , p=0.7389  , df_denom=1633, df_num=10
# ssr based chi2 test:   chi2=6.9424  , p=0.7309  , df=10
# likelihood ratio test: chi2=6.9279  , p=0.7322  , df=10
# parameter F test:         F=0.6854  , p=0.7389  , df_denom=1633, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.6420  , p=0.7937  , df_denom=1630, df_num=11
# ssr based chi2 test:   chi2=7.1612  , p=0.7859  , df=11
# likelihood ratio test: chi2=7.1457  , p=0.7872  , df=11
# parameter F test:         F=0.6420  , p=0.7937  , df_denom=1630, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.6316  , p=0.8167  , df_denom=1627, df_num=12
# ssr based chi2 test:   chi2=7.6956  , p=0.8084  , df=12
# likelihood ratio test: chi2=7.6778  , p=0.8098  , df=12
# parameter F test:         F=0.6316  , p=0.8167  , df_denom=1627, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.5877  , p=0.8658  , df_denom=1624, df_num=13
# ssr based chi2 test:   chi2=7.7671  , p=0.8584  , df=13
# likelihood ratio test: chi2=7.7489  , p=0.8596  , df=13
# parameter F test:         F=0.5877  , p=0.8658  , df_denom=1624, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.6212  , p=0.8494  , df_denom=1621, df_num=14
# ssr based chi2 test:   chi2=8.8526  , p=0.8404  , df=14
# likelihood ratio test: chi2=8.8290  , p=0.8418  , df=14
# parameter F test:         F=0.6212  , p=0.8494  , df_denom=1621, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.5800  , p=0.8921  , df_denom=1618, df_num=15
# ssr based chi2 test:   chi2=8.8667  , p=0.8844  , df=15
# likelihood ratio test: chi2=8.8429  , p=0.8856  , df=15
# parameter F test:         F=0.5800  , p=0.8921  , df_denom=1618, df_num=15

# %%
Granger1
# Out:
#   windowSize (ms) Modo Direction Lag       Chi2         p
# 0             100    M      A->B   8  22.513402  0.004152
# 0             100    S      A->B   8   6.457250  0.598659
# 0             100    M      B->A   8   8.429402  0.394344
# 0             100    S      B->A   8  14.161447  0.079170
# 0             100    M      A->B   9  24.282934  0.003989
# 0             100    S      A->B   9   8.460153  0.491817
# 0             100    M      B->A   9   8.453103  0.491107
# 0             100    S      B->A   9  14.714762  0.101110
# 0             100    M      A->B  10  24.770670  0.005974
# 0             100    S      A->B  10   8.718299  0.562664
# 0             100    M      B->A  10   8.458613  0.586172
# 0             100    S      B->A  10  16.427347  0.090213
# 0             100    M      A->B  11  25.089877  0.009120
# 0             100    S      A->B  11   8.764372  0.647377
# 0             100    M      B->A  11  10.711696  0.470292
# 0             100    S      B->A  11  16.722844  0.119246
# 0             100    M      A->B  12  27.167546  0.007573
# 0             100    S      A->B  12  13.337070  0.350078
# 0             100    M      B->A  12  12.832289  0.384290
# 0             100    S      B->A  12  17.597666  0.131906
# 0             100    M      A->B  13  26.920220  0.013207
# 0             100    S      A->B  13  14.939548  0.316693
# 0             100    M      B->A  13  13.432281  0.418311
# 0             100    S      B->A  13  18.127463  0.156942
# 0             100    M      A->B  14  27.661747  0.016351
# 0             100    S      A->B  14  15.062370  0.380266
# 0             100    M      B->A  14  13.963101  0.456127
# 0             100    S      B->A  14  17.366495  0.242843
# 0             100    M      A->B  15  32.154614  0.006434
# 0             100    S      A->B  15  15.852309  0.398987
# 0             100    M      B->A  15  17.278571  0.306372
# 0             100    S      B->A  15  17.371647  0.303862

# %%
Granger2
# Out:
#   windowSize (ms) Modo Direction Lag       Chi2         p
# 0             100    M      C->D   8  16.533782  0.036158
# 0             100    S      C->D   8   7.044966  0.534215
# 0             100    M      D->C   8   8.990209  0.345664
# 0             100    S      D->C   8   4.887697  0.771058
# 0             100    M      C->D   9  17.176770  0.047140
# 0             100    S      C->D   9   7.374079  0.600912
# 0             100    M      D->C   9   8.998483  0.440418
# 0             100    S      D->C   9   4.985017  0.837034
# 0             100    M      C->D  10  19.809286  0.032085
# 0             100    S      C->D  10  15.610041  0.113600
# 0             100    M      D->C  10  12.745970  0.241393
# 0             100    S      D->C  10   5.656400  0.844869
# 0             100    M      C->D  11  19.883708  0.048425
# 0             100    S      C->D  11  15.773895  0.152721
# 0             100    M      D->C  11  13.031116  0.295140
# 0             100    S      D->C  11   7.439242  0.765057
# 0             100    M      C->D  12  19.914534  0.070827
# 0             100    S      C->D  12  15.733286  0.207639
# 0             100    M      D->C  12  15.316295  0.228581
# 0             100    S      D->C  12   8.711135  0.730630
# 0             100    M      C->D  13  19.999346  0.098097
# 0             100    S      C->D  13  15.653465  0.273152
# 0             100    M      D->C  13  15.363883  0.290022
# 0             100    S      D->C  13   9.856604  0.709473
# 0             100    M      C->D  14  20.987188  0.105264
# 0             100    S      C->D  14  16.428634  0.293348
# 0             100    M      D->C  14  17.482124  0.236393
# 0             100    S      D->C  14  10.130650  0.756408
# 0             100    M      C->D  15  22.607159  0.096271
# 0             100    S      C->D  15  17.151316  0.316021
# 0             100    M      D->C  15  21.724162  0.119141
# 0             100    S      D->C  15  10.619994  0.782972

# %%
Granger3

A->B
C->
# Out:
#   windowSize (ms) Modo Direction Lag       Chi2         p
# 0             100    M      E->F   8  19.343636  0.013523
# 0             100    S      E->F   8   6.354188  0.614961
# 0             100    M      F->E   8   6.924961  0.547114
# 0             100    S      F->E   8   2.646619  0.955792
# 0             100    M      E->F   9  19.865906  0.019353
# 0             100    S      E->F   9   6.937067  0.651930
# 0             100    M      F->E   9   6.971675  0.642551
# 0             100    S      F->E   9   4.708256  0.863083
# 0             100    M      E->F  10  23.243199  0.010300
# 0             100    S      E->F  10   7.642171  0.673069
# 0             100    M      F->E  10  11.744745  0.305892
# 0             100    S      F->E  10   6.942387  0.738907
# 0             100    M      E->F  11  24.324986  0.011952
# 0             100    S      E->F  11   7.723300  0.746967
# 0             100    M      F->E  11  11.832932  0.380337
# 0             100    S      F->E  11   7.161154  0.793739
# 0             100    M      E->F  12  24.769109  0.016705
# 0             100    S      E->F  12   8.010139  0.793357
# 0             100    M      F->E  12  11.837187  0.463350
# 0             100    S      F->E  12   7.695646  0.816677
# 0             100    M      E->F  13  26.307581  0.016262
# 0             100    S      E->F  13   8.650271  0.808487
# 0             100    M      F->E  13  11.630796  0.562884
# 0             100    S      F->E  13   7.767075  0.865757
# 0             100    M      E->F  14  26.693932  0.022216
# 0             100    S      E->F  14  13.186000  0.530429
# 0             100    M      F->E  14  12.658639  0.558893
# 0             100    S      F->E  14   8.852644  0.849419
# 0             100    M      E->F  15  29.496016  0.014766
# 0             100    S      E->F  15  13.971988  0.547908
# 0             100    M      F->E  15  13.051868  0.603930
# 0             100    S      F->E  15   8.866680  0.892113

# %%
pd.read_csv(filesPath[0])
# Out:
#       Pulse X  Pulse Y Resultado
# 0       False     True         Q
# 1       False    False         Q
# 2       False    False         Q
# 3        True    False         Q
# 4       False    False         Q
# ...       ...      ...       ...
# 8553    False    False         A
# 8554     True    False         A
# 8555    False    False         A
# 8556    False    False         A
# 8557    False    False         A
#
# [8558 rows x 3 columns]

# %%
pd.read_csv(filesPath[2])
# Out:
#       Pulse X  Pulse Y Resultado
# 0       False     True         Q
# 1        True    False         Q
# 2       False    False         Q
# 3       False    False         Q
# 4       False    False         Q
# ...       ...      ...       ...
# 5541    False     True         C
# 5542    False    False         C
# 5543    False    False         C
# 5544    False    False         C
# 5545    False    False         C
#
# [5546 rows x 3 columns]

# %%
pd.read_csv(filesPath[4])
# Out:
#       Pulse X  Pulse Y Resultado
# 0        True    False         F
# 1       False    False         F
# 2       False    False         F
# 3       False    False         F
# 4       False    False         F
# ...       ...      ...       ...
# 5551    False    False         E
# 5552    False     True         E
# 5553    False    False         E
# 5554    False    False         E
# 5555     True    False         E
#
# [5556 rows x 3 columns]
